# %% [markdown]
# ## NER - Natasha

# %% [markdown]
# Natasha  - питоновская библиотека для извлечения именованных сущностей. Она похоже на Tomita-parser, но в ней все на чистом питоне, с открытым кодом и активно развивается.

# %% [markdown]
# Если быть точнее, то natasha - набор готовых правил для парсера yargy.

# %% [markdown]
# Есть например готовые правила для извлечения персон.

# %%
# Установить можно через pip.
from natasha import NamesExtractor, DatesExtractor, AddressExtractor

# %%
sents = '''«Ни́ва» (код кузова ВАЗ-2121 для трёхдверной модели и ВАЗ-2131 для пятидверной, в разное время также выпускалась под названиями Lada Niva, LADA 4x4 и LADA Niva Legend) — советский и российский автомобиль повышенной проходимости — внедорожник малого класса с несущим кузовом и постоянным полным приводом. Серийно производится с 5 апреля 1977 года (до 2006 года продавался под именем ВАЗ-2121 «Ни́ва» на внутреннем рынке, и как Lada Niva на экспортных рынках[2][3], с 2006 по 2021 годы под именем LADA 4x4, с 2021 года — LADA Niva Legend).

Британский исследователь советского автомобилестроения Энди Томпсон считает «Ниву» прямым предком класса компактных кроссоверов, на который ориентировались создатели автомобиля Suzuki Vitara[4]. Некоторыми экспертами называется лучшим автомобилем в истории Волжского автозавода[5], является самой успешной экспортной моделью ВАЗа за всю историю[6].

Концепция, история создания и обновления
В 1969—1970 годах главный конструктор ВАЗа В. С. Соловьёв вышел с инициативой о разработке внедорожника для жителей сельских районов. Его предложение стало результатом проработки так называемого «типажа» Минавтопрома СССР на 1971—1980 годы, на тот момент времени делегированного ИМЗ (Ижмаш). Уже были созданы прототипы АЗЛК-415 и −416 и Иж-14, однако эти автомобили не были готовы к серийному производству.

Летом 1970 года председатель Совета министров СССР Алексей Косыгин поставил перед коллективами ВАЗа, АЗЛК и Ижмаша задачу создать легковой автомобиль повышенной проходимости с комфортом массовых легковых моделей. В частности, по воспоминаниям участников встречи в ОГК (отдел главного конструктора) на ВАЗе, после показа ему металло-гипсового макета «автомобиля № 2» (люксовый вариант «Жигулей», впоследствии ВАЗ-2103) он сказал следующее:

«Работа с Fiat на этом заканчивается (так обусловлено контрактом), и дальше придётся надеяться только на себя. Так вот, первым вашим самостоятельным шагом должно быть создание автомобиля повышенной проходимости на базе „Жигулей“ для наших сельчан. А они невольно оказались обделёнными — миллионам горожан мы дадим сейчас современный легковой автомобиль, а для села он мало пригоден, особенно для нашей „глубинки“»[7].

В апреле 1971 года состоялся первый техсовет, на котором выбирали конструктивные особенности нового автомобиля. Сторонники классического подхода к проектированию предлагали вариант с рамным кузовом, зависимыми подвесками колёс, барабанными тормозами спереди и сзади. Были и более радикальные предложения, включая поперечную компоновочную схему и независимые подвески. Конструкторы начали разработку документации летом 1971 года, а уже в апреле 1972 года был изготовлен первый опытный образец[8].

В интервью журналу «Итоги» создатель «Нивы» Пётр Михайлович Прусов рассказал, что автомобиль назвали в честь детей Прусова — Натальи и Ирины, и детей первого главного конструктора ВАЗа В. С. Соловьёва — Вадима и Андрея[9][10]. Однако позднее эта информация была опровергнута «АВТОВАЗом»; в частности, в опровержении указано, что старшего сына Соловьёва звали не Вадимом, а Сергеем, а Ирина Прусова родилась уже после того, как было предложено название[11].

Лада 4x4 Бронто Марш-1 — снегоболотоход («пневматик») на колёсах сверхнизкого давления на агрегатах ВАЗ-21213. Мелкосерийно производят в ОАО «ПСА Бронто» с 1997 года.
АПАЛ-21541 «Сталкер» — модификация на базе узлов и агрегатов ВАЗ-21214, планировали к серийному выпуску на базе завода «Пищемаш» в городе Аргуне Чеченской республики. Мелкосерийно производится ООО «АПАЛ» с 2003 года.
ФВК-2302 «Бизон» — пикап с рамным шасси на базе агрегатов «Нивы». Пикап с короткой двухместной кабиной и деревянной платформой мелкосерийно производили в тольяттинской фирме «Восточное кольцо» в 1993-1995 гг. Усиленная задняя подвеска «Бизона» — рессорная. Пикап спросом не пользовался.
ВАЗ-2123 — российский компактный внедорожник второго поколения, опытно-промышленные партии которого производили на ВАЗе в 2001-2002 гг. Сохранили преемственность со старой «Нивой» по агрегатам и после существенной модернизации запустили в крупносерийное производство с сентября 2002 года на мощностях СП GM-автоВАЗ как Chevrolet Niva (с июля 2020 года как LADA Niva). Часть агрегатов от Chevrolet Niva (например, ГУР фирмы ZF) со временем перевели на LADA 4x4.
Нива Куб — российский минивэн от ООО «Промтех» (из Нижнего Новгорода), длины 4900 мм, с колёсной базой 3050 мм, с двигателем мощности 106 л. с., грузоподъёмности 850 кг и снаряжённой массы 1300 кг. Отдельного грузового отсека нет, кузов более широкий по сравнению с базовой моделью[60][61].
Нива «Карелия» — российский дом на колёсах в категории «вахтовый автобус»[62].'''.split("\n")

# %%
extractor = NamesExtractor()

# %%
dates = DatesExtractor()
addr = AddressExtractor()

# %%
extractor("\n".join(sents))
# Out:
# Matches('«Ни́ва» (код кузова ВАЗ-2121 для трёхдверной модели и ВАЗ-2131 для пятидверной, в разное время также выпускалась под названиями Lada Niva, LADA 4x4 и LADA Niva Legend) - советский и российский автомобиль повышенной проходимости - внедорожник малого класса с несущим кузовом и постоянным полным приводом. Серийно производится с 5 апреля 1977 года (до 2006 года продавался под именем ВАЗ-2121 «Ни́ва» на внутреннем рынке, и как Lada Niva на экспортных рынках[2][3], с 2006 по 2021 годы под именем LADA 4x4, с 2021 года - LADA Niva Legend).\n\nБританский исследователь советского автомобилестроения Энди Томпсон считает «Ниву» прямым предком класса компактных кроссоверов, на который ориентировались создатели автомобиля Suzuki Vitara[4]. Некоторыми экспертами называется лучшим автомобилем в истории Волжского автозавода[5], является самой успешной экспортной моделью ВАЗа за всю историю[6].\n\nКонцепция, история создания и обновления\nВ 1969-1970 годах главный конструктор ВАЗа В. С. Солов
# ...

# %%
dates("\n".join(sents))
# Out:
# Matches('«Ни́ва» (код кузова ВАЗ-2121 для трёхдверной модели и ВАЗ-2131 для пятидверной, в разное время также выпускалась под названиями Lada Niva, LADA 4x4 и LADA Niva Legend) - советский и российский автомобиль повышенной проходимости - внедорожник малого класса с несущим кузовом и постоянным полным приводом. Серийно производится с 5 апреля 1977 года (до 2006 года продавался под именем ВАЗ-2121 «Ни́ва» на внутреннем рынке, и как Lada Niva на экспортных рынках[2][3], с 2006 по 2021 годы под именем LADA 4x4, с 2021 года - LADA Niva Legend).\n\nБританский исследователь советского автомобилестроения Энди Томпсон считает «Ниву» прямым предком класса компактных кроссоверов, на который ориентировались создатели автомобиля Suzuki Vitara[4]. Некоторыми экспертами называется лучшим автомобилем в истории Волжского автозавода[5], является самой успешной экспортной моделью ВАЗа за всю историю[6].\n\nКонцепция, история создания и обновления\nВ 1969-1970 годах главный конструктор ВАЗа В. С. Солов
# ...

# %%
addr("\n".join(sents))
# Out:
# Matches('«Ни́ва» (код кузова ВАЗ-2121 для трёхдверной модели и ВАЗ-2131 для пятидверной, в разное время также выпускалась под названиями Lada Niva, LADA 4x4 и LADA Niva Legend) - советский и российский автомобиль повышенной проходимости - внедорожник малого класса с несущим кузовом и постоянным полным приводом. Серийно производится с 5 апреля 1977 года (до 2006 года продавался под именем ВАЗ-2121 «Ни́ва» на внутреннем рынке, и как Lada Niva на экспортных рынках[2][3], с 2006 по 2021 годы под именем LADA 4x4, с 2021 года - LADA Niva Legend).\n\nБританский исследователь советского автомобилестроения Энди Томпсон считает «Ниву» прямым предком класса компактных кроссоверов, на который ориентировались создатели автомобиля Suzuki Vitara[4]. Некоторыми экспертами называется лучшим автомобилем в истории Волжского автозавода[5], является самой успешной экспортной моделью ВАЗа за всю историю[6].\n\nКонцепция, история создания и обновления\nВ 1969-1970 годах главный конструктор ВАЗа В. С. Солов
# ...

# %% [markdown]
# Видно, что извлекается не очень хорошо. К тому же в реальной задаче нам потребуется извлекать ещё какие-то аттрибуты сущностей и группировать их в факты. И не обязательно этих типов. Поэтому полезно разобраться с самим парсером yargy.

# %% [markdown]
# Документация yargy: https://yargy.readthedocs.io/ru/latest/reference.html

# %% [markdown]
# Лучше всего с такими штуками разбираться на практике. Давайте попробуем написать правила для извлечения персон. Каждая персона должна описываться 3 полями - Имя, Фамилия, Отчество. Также у Персоны должны быть атрибуты - должность и место работы.

# %% [markdown]
# За основу возьмем пример из документации:

# %%
from yargy import Parser, rule, and_, or_
from yargy.tokenizer import MorphTokenizer, INT
from yargy.pipelines import morph_pipeline
from yargy.interpretation import fact
from yargy.predicates import gram
from IPython.display import display


Person = fact(
    'Person',
    ['position', 'name']
)
Name = fact(
    'Name',
    ['first', 'patronim', 'last']
)


POSITION = morph_pipeline([
    'премьер министр',
    'президент',
    'председатель',
    'исследователь',
    'конструктор',
    'председатель Совета министров СССР'
])

NAME_rule = rule(
    gram('Name').interpretation(
        Name.first
    ),
    gram('Patr').interpretation(
        Name.patronim
    ).optional(),
    gram('Surn').interpretation(
        Name.last
    )
)

NAME = NAME_rule.interpretation(
    Name
)

PERSON = rule(
    POSITION.interpretation(
        Person.position.inflected()
    ).optional(),
    NAME.interpretation(
        Person.name
    )
).interpretation(
    Person
)

parser = Parser(PERSON)
result = set()
for match in parser.findall("\n".join(sents)):
    result.add(match.fact)
result
# Out:
# {Person(position='председатель совет министр ссср',
#         name=Name(first='Алексей',
#                   patronim=None,
#                   last='Косыгин')),
#  Person(position=None,
#         name=Name(first='Ирина',
#                   patronim=None,
#                   last='Прусова')),
#  Person(position=None,
#         name=Name(first='Пётр',
#                   patronim='Михайлович',
#                   last='Прусов')),
#  Person(position=None,
#         name=Name(first='Энди',
#                   patronim=None,
#                   last='Томпсон')),
#  Person(position=None,
#         name=Name(first='из',
#                   patronim=None,
#                   last='крупноузловых'))}

# %%
from yargy import Parser, rule, and_, or_, not_
from yargy.predicates import eq, gte, lte, length_eq, dictionary, normalized, gram, is_capitalized, is_title, custom

manufacturers_list = [
    'АвтоВАЗ',
    'ВАЗ',
    'Лада',
    'LADA',
    'Peugeout',
    'Land Rover',
    'УАЗ',
    'Chevrolet',
    'General Motors',
    'GM',
    'Suzuki',
    'Mercedes Benz',
    'Fiat',
    'Pininfarina S.p.A.',
    'Ижмаш',
    'Jeep',
    'Subaru',
    'ВИС',
    'АЗЛК'
]

Code = fact(
    'Code',
    ['manufacturer', 'code']
)
Car = fact(
    'Car',
    ['manufacturer', 'model']
)
Model = fact(
    'Model',
    ['name', 'code']
)

MANUFACTURER = morph_pipeline(manufacturers_list).interpretation(
    Car.manufacturer.normalized()
)

# Выделяем принятый в российском автопроме код, обозначающий автомобиль: 
# аббревиатура завода + индекс, например, "ВАЗ-2123". Реально каждая цифра имеет значение, 
# но в рамках лабораторной можно упрощённо распарсить по числовому диапазону
CODE = rule(
    MANUFACTURER.interpretation(
        Code.manufacturer
    ),
    '-',
    and_(
        gte(1),
        lte(30000)
    ).interpretation(
        Code.code
    )
).interpretation(
    Code
)

# наименование модели (в тексте встречается в кавычках и без)
NAME_WITHOUT_QUOTAS = rule(
    and_(
        custom(lambda word : len(word) > 1),
        is_title(),
        custom(lambda word : word not in manufacturers_list),
        not_(or_(gram('Name'), gram('Surn'), gram('Patr'))),
        not_(or_(gram('PREP'), gram('VERB'))),
        gram('NOUN'),
    )
)

NAME_WITH_QUOTAS = rule(
    "«",
    NAME_WITHOUT_QUOTAS,
    "»"
)

NAME_LATIN = rule(
    or_(
        and_(
            custom(lambda word : word.istitle(), types="LATIN"),
            custom(lambda word : len(word) > 1),
            custom(lambda word : word not in manufacturers_list),
        )
    )
).repeatable(max=5)

MODEL_NAME = or_(
    NAME_LATIN,
    NAME_WITH_QUOTAS,
    NAME_WITHOUT_QUOTAS,
)

# модель может быть идентифицирована как по имени, так и по коду, но обязательно должно быть хоть что-то
MODEL = rule(
    or_(
        rule(
            CODE.interpretation(
                Model.code
            ),
            MODEL_NAME.interpretation(
                Model.name.inflected()
            ).optional()
        ),
        rule(
            MODEL_NAME.interpretation(
                Model.name.inflected()
            ),
            CODE.interpretation(
                Model.code
            ).optional()
        ),
    )
).interpretation(
    Model
)

# машину в целом можно опознать как по сочетанию производитель+имя модели, так и по коду.
# в случае производитель+имя из текста можно вытащить и иностранные модели
CAR = rule(
    MANUFACTURER.interpretation(
        Car.manufacturer
    ).optional(),
    MODEL.interpretation(
        Car.model
    )
).interpretation(
    Car
)

car_parser = Parser(CAR)

for match in car_parser.findall("\n".join(sents)):
    print(match.fact, match.span)
# match.tree.as_dot
# Out:
# Car(manufacturer=None, model=Model(name=None, code=Code(manufacturer='ВАЗ', code='2121'))) [20, 28)
# Car(manufacturer=None, model=Model(name=None, code=Code(manufacturer='ВАЗ', code='2131'))) [54, 62)
# Car(manufacturer=None, model=Model(name='lada niva', code=None)) [128, 137)
# Car(manufacturer='LADA', model=Model(name='niva legend', code=None)) [150, 166)
# Car(manufacturer=None, model=Model(name=None, code=Code(manufacturer='ВАЗ', code='2121'))) [382, 390)
# Car(manufacturer=None, model=Model(name='lada niva', code=None)) [426, 435)
# Car(manufacturer='LADA', model=Model(name='niva legend', code=None)) [519, 535)
# Car(manufacturer=None, model=Model(name='«нива»', code=None)) [615, 621)
# Car(manufacturer='Suzuki', model=Model(name='vitara', code=None)) [716, 729)
# Car(manufacturer=None, model=Model(name='волжский', code=None)) [796, 805)
# Car(manufacturer=None, model=Model(name='концепция', code=None)) [889, 898)
# ...

# %% [markdown]
# Посмотрим, что получается:

# %%
matches = set()

for sent in sents:
    for match in car_parser.findall(sent):
        # немного руками подправим результат от лишних слов и свяжем данные, поскольку это уже работа
        # логики, а не парсеров
        if not (match.fact.manufacturer == None and match.fact.model.code == None):
            hm = match.fact
            if (match.fact.model != None
                and (match.fact.model.code and type(match.fact.model.code) != str)
                and match.fact.model.code.manufacturer != None
                and match.fact.manufacturer == None):
                hm.manufacturer = match.fact.model.code.manufacturer
            matches.add(hm)

# %%
matches
# Out:
# {Car(manufacturer='Chevrolet',
#      model=Model(name='niva',
#                  code=None)),
#  Car(manufacturer='Jeep',
#      model=Model(name='cherokee',
#                  code=None)),
#  Car(manufacturer='LADA',
#      model=Model(name='niva legend',
#                  code=None)),
#  Car(manufacturer='LADA',
#      model=Model(name='niva travel',
#                  code=None)),
#  Car(manufacturer='LADA',
#      model=Model(name='niva',
#                  code=None)),
#  Car(manufacturer='Subaru',
#      model=Model(name='leone',
#                  code=None)),
#  Car(manufacturer='Suzuki',
#      model=Model(name='vitara',
#                  code=None)),
#  Car(manufacturer='АЗЛК',
#      model=Model(name=None,
#                  code=Code(manufacturer='АЗЛК',
#                            code='415'))),
#  Car(manufacturer='ВАЗ',
#      model=Model(name='«бора»',
#                  code=Code(manufacturer='ВАЗ',
#                            code='21'))),
# ...

# %%
len(matches)
# Out:
# 46

# %% [markdown]
# Чтобы проверить какие морфологические тэги приписываются словам, можно использовать MorphTokenizer.

# %%
tokenizer = MorphTokenizer()

# %%
list(tokenizer('4x4'))
# Out:
# [Token('4', [0, 1), 'INT'),
#  Token('x', [1, 2), 'LATIN'),
#  Token('4', [2, 3), 'INT')]

# %% [markdown]
# ## Задача на семинар:
# Доработать правила так, чтобы извлекалось как можно больше правильных фактов.
#
# Документация yargy вот тут - https://yargy.readthedocs.io/ru/latest/reference.html
